# %% [markdown]
# # Домашнее задание 1
# ## Harry Potter and the Action Prediction Challenge from Natural Language
#
#
# *deadline*: 19 марта 2026, 23:59
#
# В этом домашнем задании вы будете работать с корпусом Harry Potter and the Action Prediction Challenge. Корпус собран из фанфиков о Гарри Поттере и состоит из двух частей: 1) сырые тексты, 2) фрагменты текстов, описывающих ситуацию, в которой произнесено заклинание.
#
# Корпус описан в статье: https://arxiv.org/pdf/1905.11037.pdf
#
# David Vilares and Carlos Gómez-Rodríguez. Harry Potter and the Action Prediction Challenge from Natural Language. 2019 Annual Conference of the North American Chapter of the Association for Computational Linguistics. To appear.
#
# Код для сбора корпуса находится в репозитории: https://github.com/aghie/hpac . Корпус можно скачать по инструкции из этого репозитория, но для экономии времени авторы задания уже скачали и подготовили данные к работе.
#
# Ссылки на собранный корпус:
# * Сырые тексты:  https://www.dropbox.com/s/23xet9kvbqna1qs/hpac_raw.zip?dl=0
# * Токенизированные тексты в нижнем регистре: https://www.dropbox.com/s/gwfgmomdbetvdye/hpac_lower_tokenized.zip?dl=0
# * train-test-dev: https://www.dropbox.com/s/3vdz0mouvex8abd/hpac_splits.zip?dl=0
#
# Часть 1 задания должны быть выполнены на полных текстах (сырых или предобработанных -- на ваше усмотрение), Остальные части – на корпусе с разбиением на тестовое, отладочное и обучающее множества. Тестовое множество должно быть использовано исключительно для тестирования моделей, обучающее и отладочное – для выбора модели и параметров.
#
# В статье и репозитории вы найдете идеи, которые помогут вам выполнить домашнее задание. Их стоит воспринимать как руководство к действию, не нужно их копировать и переиспользовать. Обученные модели использовать также не нужно, но код для их обучения можно использовать как подсказку.

# %% [markdown]
# ## Часть 1. [2 балла] Эксплоративный анализ
#
# 1. [0.5 балла] Найдите топ-100 слов в корпусе по частоте с учетом стоп-слов.
# 2. [0.5 балла] Найдите топ-10 по частоте: имен, пар имя + фамилия, пар вида ''профессор'' + имя / фамилия.

# %%
## Ваше решение

# %% [markdown]
# 3. [0.5 балла] Если необходимо, проведите предобработку текста (уберите стоп-слова, проведите лемматизацию, если требуется и т.д.)

# %%
## Ваше решение

# %% [markdown]
# 4. [0.5 балла] Исследуйте распределение длины текстов (в словах) в корпусе:
#
#     1. Постройте гистограмму длины фрагментов.
#     2. Оцените, есть ли «хвосты» (очень длинные или очень короткие тексты). Сделайте вывод, может ли это повлиять на обучение моделей (при необходимости проведите обрезку или padding).

# %%
## Ваше решение

# %% [markdown]
# ## Часть 2. [2 + 2 балла] Модели представления слов
# Обучите модель представления слов (word2vec, GloVe, fastText или любую другую) на материале корпуса HPAC.
# 1. Продемонстрируйте, как работает поиск синонимов, ассоциаций, лишних слов в обученной модели.
# 2. Визуализируйте топ-100 слов по частоте без учета стоп-слов (п. 1.1) с помощью TSNE или UMAP (https://umap-learn.readthedocs.io).

# %%
## Ваше решение

# %% [markdown]
# [бонус, 2 балла] Обучите две разные модели представления слов (например, word2vec CBOW и fastText, или возьмите одну модель но с разными размерностями векторов).
#
# * Сравните качество ближайших соседей для фиксированного списка из 10–15 слов (например, имена персонажей, ключевые заклинания).
#
# *  Сравните визуализацию (t-SNE/UMAP) для этих двух моделей: есть ли заметные отличия в кластерах? какая модель даёт более «осмысленные» группы?

# %%
## Ваше решение

# %% [markdown]
# ## Часть 3. [7 баллов] Классификация текстов
# Задача классификации формулируется так: данный фрагмент фанфика описывают какую-то ситуацию, которая предшествует произнесению заклинания. Требуется по тексту предсказать, какое именно заклинание будет произнесено. Таким образом, заклинание - это фактически метка класса. Основная мера качества – macro $F_1$ и метрики Precision - Recall по каждому классу.
#
# Как обычно, используем фрагменты из множества train для обучения, из множества dev для отладки, из множества test – для тестирования и получения итоговых результатов.
#
# Вам нужно обучить три модели и сравните результаты между собой. Кроме того для каждого пункта (кроме 3) проведите обучение несколько (2-3) раз с разными seed и вместе в метриками сообщите уровень дисперсии (std).

# %% [markdown]
# 1. [1 балл] Используйте fastText в качестве baseline-классификатора.

# %%
## Ваше решение

# %% [markdown]
# 2. [3 балла] Используйте сверточные сети в качестве более продвинутого классификатора. Поэкспериментируйте с количеством и размерностью фильтров, используйте разные размеры окон, попробуйте использовать $k$-max pooling.
#
#     Используйте обученные в части 2 векторы слов, как инициализацию эмбеддингов. Сравните качество модели с случайной инициализацией эмбеддингов и инициализацией вашими эмбеддингами. В отчёте обсудите, помогает ли инициализация и насколько (по macro F1).

# %%
## Ваше решение

# %% [markdown]
# 3. [1 балл] Попробуйте расширить обучающее множество за счет аугментации данных. Если вам понадобится словарь синонимов, можно использовать WordNet (ниже вы найдете примеры).

# %%
## Ваше решение

# %% [markdown]
# 4. [2 балла] Наконец, попробуйте взять предобученную модель с HuggingFace и использовать ее в качестве классификатора. Вы можете взять любую encoder-модель (то есть классификация проводится с помощью метки [CLS]). Аналогично попробуйте различные параметры длины последовательности и выберите лучший.

# %%
## Ваше решение

# %% [markdown]
# ## Часть 4. [3 балла] Анализ ошибок
#
# Выберите одну из моделей из пункта 3 (сверточную либо трансформер) и проанализируйте ее работу:
# *  Рассмотрите 20-30 неправильно проклассифицированных текстов, разбейте ошибки на 2–3 типа (например: очень короткий контекст, длинный запутанный контекст, редкие заклинания, неоднозначные ситуации). Приведите по 1–2 примера на каждый тип ошибки и прокомментируйте, почему, на ваш взгляд, модель ошиблась и что с этим можно было бы сделать
#
# * Далее оцените качество классификаторов на частых и редких классах. Какие классы чаще всего оказываются перепутаны? Можете ли вы объяснить, почему именно такие классы путаются?

# %%
## Ваше решение

# %% [markdown]
# ## Часть 5. [1 балл] Итоги
# Напишите краткое резюме проделанной работы.
#
# Если вы читали сами книги про Гарри Поттера или фанфики о нем, ответьте, помогло ли вам знание предметной области в выполнении домашнего задания?

# %%
## Ваше решение

# %% [markdown]
# ## Вспомогательные методы

# %% [markdown]
# ### Данные
# Сырые тексты

# %%
# !unzip hpac_source

# %%
# !ls hpac_source | wc -l

# %%
# !unzip hpac_splits

# %% [markdown]
# train, test, dev файлы

# %%
import pandas as pd
df = pd.read_csv('hpac_splits/hpac_training_128.tsv', sep = '\t', header = None)

# %%
df.head()

# %%
df.iloc[0][1], df.iloc[0][2]

# %% [markdown]
# ### Как использовать WordNet из nltk?

# %%
# скачиваем WordNet
import nltk
nltk.download('wordnet')

# %%
# слово -> множество синсетов (синонимов разных смыслов исходного слова)
from nltk.corpus import wordnet as wn
wn.synsets('magic')

# %%
# посмотрим, что внутри одного синсета
wn.synsets('magic')[1].lemmas()[0]

# %%
# возьмем лемму одного из слов из синсета
wn.synsets('magic')[1].lemmas()[-1].name()
